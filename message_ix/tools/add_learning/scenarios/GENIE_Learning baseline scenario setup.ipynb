# %% [markdown]
# # GENIE: Baseline scenario with learning
#
# **Pre-requisites**
# - You have the *MESSAGEix* framework installed and working
# - You have run Westeros baseline scenario (``westeros_baseline.ipynb``) and solved it successfully

# %%
import ixmp
import message_ix
import numpy as np
import pandas as pd
import yaml

from collections.abc import Mapping
from itertools import repeat
from message_ix.models import MESSAGE_ITEMS
from message_ix.utils import make_df

from message_ix.tools.add_learning import add_learning


# %matplotlib inline

# %%
mp = ixmp.Platform("local")

# %% [markdown]
# ## Making a clone of the existing scenario 'baseline'

# %% [markdown]
# Dump scenario to excel nad create a scenario from excel

# %%
base_is_new = "yes_sandbox" # select "Yes" or "No"

if base_is_new == "yes_engage":
    data_file = "ENGAGE_SSP2_v417_NPi2020-con-prim-dir-ncr.xlsx"

    # Creating a new, empty scenario
    base = message_ix.Scenario(
        mp, model="GENIE", scenario="baseline", version="new"
    )
    # Fill the empty scenario with data from excel
    base.read_excel(data_file, add_units=True, init_items=True)

elif base_is_new == "yes_sandbox":
    data_file = "GENIE_sandbox_baseline.xlsx"

    # Creating a new, empty scenario
    base = message_ix.Scenario(
        mp, model="GENIE_sandbox", scenario="baseline", version="new"
    )
    
    # Dump the scenario data to excel
    base.read_excel(data_file, add_units=True, init_items=True)

elif base_is_new == "no_engage":
    base = message_ix.Scenario(
        mp, model="GENIE", scenario="baseline",
    )

else:
    base = message_ix.Scenario(
        mp, model="GENIE_sandbox", scenario="baseline",
    )

# %% [markdown]
# Clone baseline scenario and add learning parameters

# %%
scen = base.clone(
    "GENIE_sandbox",
    "learning",
    "GENIE baseline scenario with learning",
    keep_solution=False,
)

scen.check_out()

# %%
scen.par('inv_cost', filters={'technology':['dac_1_exports','dac_2_exports','dac_3_exports','dac_4_exports','dac_5_exports'],
                              'node_loc':'R11_WEU','year_vtg':2025})

scen.par('relation_activity', filters={'technology':'dac_1_exports'})
# Out:
#           relation node_rel  year_rel node_loc     technology  year_act mode  \
# 0     CO2_Emission  R11_AFR      2030  R11_AFR  dac_1_exports      2030   M1
# 1     CO2_Emission  R11_AFR      2035  R11_AFR  dac_1_exports      2035   M1
# 2     CO2_Emission  R11_AFR      2040  R11_AFR  dac_1_exports      2040   M1
# 3     CO2_Emission  R11_AFR      2045  R11_AFR  dac_1_exports      2045   M1
# 4     CO2_Emission  R11_AFR      2050  R11_AFR  dac_1_exports      2050   M1
# ...            ...      ...       ...      ...            ...       ...  ...
# 2569    DAC_mpen_c  R11_WEU      2070  R11_WEU  dac_1_exports      2070   M1
# 2570    DAC_mpen_c  R11_WEU      2080  R11_WEU  dac_1_exports      2080   M1
# 2571    DAC_mpen_c  R11_WEU      2090  R11_WEU  dac_1_exports      2090   M1
# 2572    DAC_mpen_c  R11_WEU      2100  R11_WEU  dac_1_exports      2100   M1
# 2573    DAC_mpen_c  R11_WEU      2110  R11_WEU  dac_1_exports      2110   M1
#
#       value unit
# 0      -1.0  ???
# 1      -1.0  ???
# 2      -1.0  ???
# 3      -1.0  ???
# 4      -1.0  ???
# ...     ...  ...
# 2569    1.0  ???
# 2570    1.0  ???
# 2571    1.0  ???
# 2572    1.0  ???
# 2573    1.0  ???
#
# [2574 rows x 9 columns]

# %% [markdown]
# ## Add learning parameters to the scenario
#
# To add learning parameters to the scenario, one needs to include `add_learning(Scenario)` to the script, with `Scenario` is the name of scenario object that you want to run. In this example, we want to run `scen`, thus:

# %%
add_learning(scen)
# Out:
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# 'inv_cost_ref' data for gas_htfc is not available.
#  gas_htfc will not be considered in technology cost learning
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]
# C:\Users\pratama\Documents\GitHub\MESSAGEix\message_ix\message_ix\tools\add_learning\__init__.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_data['value'] = selected_data[selected_data['year_vtg'] == ref_year]['value'].iloc[0]

# %% [markdown]
# ## Time to Solve the Model

# %%
scen.commit(comment="GENIE_sandbox baseline with learning")
scen.set_as_default()

# %%
scen.solve(gams_args =["--learningmode=0"]) #

# %%
scen.var("OBJ")["lvl"]
# Out:
# 2681992.25

# %% [markdown]
# ## Close the connection to the database

# %%
mp.close_db()
